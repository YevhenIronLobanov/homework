# %% [markdown]
# ### *Умова задачі*
# U (всього днів) = 30
# A (дощ) = 12
# B (вітер) = 8
# C (холод) = 4
# A ∩ B = 5
# A ∩ C = 3
# B ∩ C = 2
# A ∩ B ∩ C = 1
# D (гарна погода)=?

# %% [markdown]
# ## *Розв'язання задачі за допомогою кругів Ейлера- Венна*

# %% [markdown]
# ![weather_set.jpg](attachment:weather_set.jpg)

# %%
E = 2+1+1+5+4+2
print('Кількість днів з поганою погодою:', E)
# Out:
# Кількість днів з поганою погодою: 15

# %%
D = 30-15
print ('Кількість днів з гарною погодо:', D)
# Out:
# Кількість днів з гарною погодо: 15

# %% [markdown]
# ## *Розв'язання задачі за формулою*

# %% [markdown]
# *__E = |A| + |B| + |C| - |A ∩ B| - |A ∩ C| - |B ∩ C| + |A ∩ B ∩ C|__*        #*розраховуємо кількість днів поганої погоди*

# %%
E = 12+8+4-5-3-2+1
print('Кількість днів з поганою погодою:', E)
# Out:
# Кількість днів з гарною погодою: 15

# %% [markdown]
# *_D = U-E_*

# %%
D = 30-15
print('Кількість днів з гарною погодою:', D)
# Out:
# Кількість днів з гарною погодою: 15
