# %% [markdown]
# ### *Умова задачі*
# Всього студентів 37
# A (математика) =15
# B (фізика) = 16
# C (хімія) = 19
# A ∩ B = 7
# A ∩ C = 9
# B ∩ C = 6
# A ∩ B ∩ C = 4
# |A ∪ B ∪ C| = D
# D (студенти отримали відмінно) = ?

# %% [markdown]
# ## *Розв'язання задачі за допомогою кругів Ейлера- Венна*

# %% [markdown]
# ![student_set.png](attachment:student_set.png)

# %%
D = 8+5+4+2+3+3+7
print ('Кількість студентів, що отримали хоча б одну оцінку відмінно:', D)
# Out:
# Кількість студентів, що отримали хоча б одну оцінку відмінно: 32

# %% [markdown]
# ## *Розв'язання задачі за формулою*

# %% [markdown]
# *__D = |A| + |B| + |C| - |A ∩ B| - |A ∩ C| - |B ∩ C| + |A ∩ B ∩ C|__*

# %%
D = 15+16+19-7-9-6+4
print ('Кількість студентів, що отримали хоча б одну оцінку відмінно:', D)
# Out:
# Кількість студентів, що отримали хоча б одну оцінку відмінно: 32
